# %% [markdown]
# # Iris Project

# %% [markdown]
# ## Data Exploration and Analysis

# %%
# import all libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import sklearn
import matplotlib.pyplot as plt

sns.set(color_codes = True)
# %matplotlib inline

# %%
# get versions

print("numpy:",np.__version__)
print("pandas",pd.__version__)
print("seaborn",sns.__version__)
print("maplotlib",matplotlib.__version__)
print("sklearn:",sklearn.__version__)

import sys

print("python",sys.version)
# Out:
# numpy: 1.17.4
# pandas 0.25.3
# seaborn 0.10.0
# maplotlib 3.2.1
# sklearn: 0.22.1
# python 3.7.5 (tags/v3.7.5:5c02a39a0b, Oct 15 2019, 00:11:34) [MSC v.1916 64 bit (AMD64)]

# %%
# read iris.csv

df = pd.read_csv('D:\PycharmProjects\ML_Prob\iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# add column name (header)

col = ['id','sepal length','sepal width','petal length','petal width','species/class']

# %%
df.columns = col

# %%
df
# Out:
#       id  sepal length  sepal width  petal length  petal width   species/class
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# remove first or 'id' column

df = df.drop(columns = ['id'])

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width   species/class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width species/class
# 0           5.1          3.5           1.4          0.2   Iris-setosa
# 1           4.9          3.0           1.4          0.2   Iris-setosa
# 2           4.7          3.2           1.3          0.2   Iris-setosa
# 3           4.6          3.1           1.5          0.2   Iris-setosa
# 4           5.0          3.6           1.4          0.2   Iris-setosa

# %% [markdown]
# ### Load data by seaborn and compare with df

# %%
dsns = sns.load_dataset('iris')
dsns
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dsns.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### there is slight difference in this (mean of sepal width,std of petal length etc.)

# %%
dsns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal length     150 non-null float64
# sepal width      150 non-null float64
# petal length     150 non-null float64
# petal width      150 non-null float64
# species/class    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
dsns.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
df.groupby('species/class').size()
# Out:
# species/class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(dsns,hue = 'species', height = 3, aspect = 1) # Plot pairwise relationships in a dataset.

# %%
dsns.hist(edgecolor = 'black' ,linewidth = 1.2, figsize = (12,8)) # x axis - value range, y -axis = count
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.subplot(2,2,1)
sns.violinplot(x = 'species', y = 'sepal_length', data = dsns)
plt.subplot(2,2,2)
sns.violinplot(x = 'species', y = 'sepal_width', data = dsns)
plt.subplot(2,2,3)
sns.violinplot(x = 'species', y = 'petal_length', data = dsns)
plt.subplot(2,2,4)
sns.violinplot(x = 'species', y = 'petal_width', data = dsns)

# %%
dsns.boxplot(by = 'species',figsize = (12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C4CA3A40C8>,
# ...
#       dtype=object)
